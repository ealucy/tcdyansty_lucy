# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import metpy.calc as mpcalc
from metpy.units import units

# %% [markdown]
# # *this is all for the entire dataset...should probably be doing this for a single vorticity feature?*

# %%
ds=xr.open_dataset('cm1_original/cm1out_20000101.000004.nc')

num_x = ds.ni
num_y = ds.nj
num_z = ds.nk

dx = ds['xh']*units('m')
dy = ds['yh']*units('m')
dz = ds['zh']*units('m')

u = ds['u']
v = ds['v']
w = ds['w']

x_space = 31.25*units('m')
y_space = 31.25*units('m')
z_space = 15.625*units('m')

lev = 0
u = u.isel(nk=lev,time=0)
v = v.isel(nk=lev,time=0)
w = w.isel(nk=lev,time=0)

dz[0] # z direction grid delta

# z_vort tilting term
dudz = mpcalc.first_derivative(u, delta=dz[1]-dz[0])
dvdz = mpcalc.first_derivative(v, delta=dz[1]-dz[0])
dwdy = mpcalc.first_derivative(w, delta=dy[1]-dy[0])
dwdx = mpcalc.first_derivative(w, delta=dx[1]-dx[0])

# z vort stretching term
dudx = mpcalc.first_derivative(u, delta=dx[1]-dx[0])
dvdy = mpcalc.first_derivative(v, delta=dy[1]-dy[0])
dwdz = mpcalc.first_derivative(w, delta=dz[1]-dz[0])

# z vort, y vort, x vort components
dvdx = mpcalc.first_derivative(v, delta=dx[1]-dx[0])
dudy = mpcalc.first_derivative(u, delta=dy[1]-dy[0])
dudz = mpcalc.first_derivative(u, delta=dz[1]-dz[0])
dwdx = mpcalc.first_derivative(w, delta=dx[1]-dx[0])
dwdy = mpcalc.first_derivative(w, delta=dy[1]-dy[0])
dvdz = mpcalc.first_derivative(v, delta=dz[1]-dz[0])

z_vort = dvdx - dudy
y_vort = dudz - dwdx
x_vort = dwdy - dvdz

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (ni: 1600, nj: 1600, nk: 65, time: 1)
# Coordinates:
#   * time     (time) datetime64[ns] 2000-01-01T00:00:04
# Dimensions without coordinates: ni, nj, nk
# Data variables: (12/20)
#     xh       (ni) float32 -2.498e+04 -2.495e+04 ... 2.495e+04 2.498e+04
#     yh       (nj) float32 -2.498e+04 -2.495e+04 ... 2.495e+04 2.498e+04
#     zh       (nk) float32 7.812 23.44 39.06 54.69 ... 976.6 992.2 1.008e+03
#     rain     (time, nj, ni) float32 ...
#     thflux   (time, nj, ni) float32 ...
#     qvflux   (time, nj, ni) float32 ...
#     ...       ...
#     qv       (time, nk, nj, ni) float32 ...
#     qc       (time, nk, nj, ni) float32 ...
#     qr       (time, nk, nj, ni) float32 ...
#     u        (time, nk, nj, ni) float32 ...
#     v        (time, nk, nj, ni) float32 ...
#     w        (time, nk, nj, ni) float32 ...
# Attributes:
#     Description::  CM1 Large-Eddy Simulation of idealized hurricane
#     dx (m):        31.25
# ...

# %%
ds2=xr.open_dataset('cm1out_000006.nc')

num_x = ds.ni
num_y = ds.nj
num_z = ds.nk

dx = ds['xh']*units('m')
dy = ds['yh']*units('m')
dz = ds['zh']*units('m')

u = ds['u']
v = ds['v']
w = ds['w']

x_space = 31.25*units('m')
y_space = 31.25*units('m')
z_space = 15.625*units('m')

lev = 0
u = u.isel(nk=lev,time=0)
v = v.isel(nk=lev,time=0)
w = w.isel(nk=lev,time=0)

dz[0] # z direction grid delta

# z_vort tilting term
dudz2 = mpcalc.first_derivative(u, delta=dz[1]-dz[0])
dvdz2 = mpcalc.first_derivative(v, delta=dz[1]-dz[0])
dwdy2 = mpcalc.first_derivative(w, delta=dy[1]-dy[0])
dwdx2 = mpcalc.first_derivative(w, delta=dx[1]-dx[0])

# z vort stretching term
dudx2 = mpcalc.first_derivative(u, delta=dx[1]-dx[0])
dvdy2 = mpcalc.first_derivative(v, delta=dy[1]-dy[0])
dwdz2 = mpcalc.first_derivative(w, delta=dz[1]-dz[0])

# z vort, y vort, x vort components
dvdx2 = mpcalc.first_derivative(v, delta=dx[1]-dx[0])
dudy2 = mpcalc.first_derivative(u, delta=dy[1]-dy[0])
dudz2 = mpcalc.first_derivative(u, delta=dz[1]-dz[0])
dwdx2 = mpcalc.first_derivative(w, delta=dx[1]-dx[0])
dwdy2 = mpcalc.first_derivative(w, delta=dy[1]-dy[0])
dvdz2 = mpcalc.first_derivative(v, delta=dz[1]-dz[0])

z_vort2 = dvdx - dudy
y_vort2 = dudz - dwdx
x_vort2 = dwdy - dvdz

# %%
ds3=xr.open_dataset('cm1out_000007.nc')

num_x = ds.ni
num_y = ds.nj
num_z = ds.nk

dx = ds['xh']*units('m')
dy = ds['yh']*units('m')
dz = ds['zh']*units('m')

u = ds['u']
v = ds['v']
w = ds['w']

x_space = 31.25*units('m')
y_space = 31.25*units('m')
z_space = 15.625*units('m')

lev = 0
u = u.isel(nk=lev,time=0)
v = v.isel(nk=lev,time=0)
w = w.isel(nk=lev,time=0)

dz[0] # z direction grid delta

# z_vort tilting term
dudz3 = mpcalc.first_derivative(u, delta=dz[1]-dz[0])
dvdz3 = mpcalc.first_derivative(v, delta=dz[1]-dz[0])
dwdy3 = mpcalc.first_derivative(w, delta=dy[1]-dy[0])
dwdx3 = mpcalc.first_derivative(w, delta=dx[1]-dx[0])

# z vort stretching term
dudx3 = mpcalc.first_derivative(u, delta=dx[1]-dx[0])
dvdy3 = mpcalc.first_derivative(v, delta=dy[1]-dy[0])
dwdz3 = mpcalc.first_derivative(w, delta=dz[1]-dz[0])

# z vort, y vort, x vort components
dvdx3 = mpcalc.first_derivative(v, delta=dx[1]-dx[0])
dudy3 = mpcalc.first_derivative(u, delta=dy[1]-dy[0])
dudz3 = mpcalc.first_derivative(u, delta=dz[1]-dz[0])
dwdx3 = mpcalc.first_derivative(w, delta=dx[1]-dx[0])
dwdy3 = mpcalc.first_derivative(w, delta=dy[1]-dy[0])
dvdz3 = mpcalc.first_derivative(v, delta=dz[1]-dz[0])

z_vort3 = dvdx - dudy
y_vort3 = dudz - dwdx
x_vort3 = dwdy - dvdz

# %%
ds4=xr.open_dataset('cm1out_000008.nc')

num_x = ds.ni
num_y = ds.nj
num_z = ds.nk

dx = ds['xh']*units('m')
dy = ds['yh']*units('m')
dz = ds['zh']*units('m')

u = ds['u']
v = ds['v']
w = ds['w']

x_space = 31.25*units('m')
y_space = 31.25*units('m')
z_space = 15.625*units('m')

lev = 0
u = u.isel(nk=lev,time=0)
v = v.isel(nk=lev,time=0)
w = w.isel(nk=lev,time=0)

dz[0] # z direction grid delta

# z_vort tilting term
dudz4 = mpcalc.first_derivative(u, delta=dz[1]-dz[0])
dvdz4 = mpcalc.first_derivative(v, delta=dz[1]-dz[0])
dwdy4 = mpcalc.first_derivative(w, delta=dy[1]-dy[0])
dwdx4 = mpcalc.first_derivative(w, delta=dx[1]-dx[0])

# z vort stretching term
dudx4 = mpcalc.first_derivative(u, delta=dx[1]-dx[0])
dvdy4 = mpcalc.first_derivative(v, delta=dy[1]-dy[0])
dwdz4 = mpcalc.first_derivative(w, delta=dz[1]-dz[0])

# z vort, y vort, x vort components
dvdx4 = mpcalc.first_derivative(v, delta=dx[1]-dx[0])
dudy4 = mpcalc.first_derivative(u, delta=dy[1]-dy[0])
dudz4 = mpcalc.first_derivative(u, delta=dz[1]-dz[0])
dwdx4 = mpcalc.first_derivative(w, delta=dx[1]-dx[0])
dwdy4 = mpcalc.first_derivative(w, delta=dy[1]-dy[0])
dvdz4 = mpcalc.first_derivative(v, delta=dz[1]-dz[0])

z_vort4 = dvdx - dudy
y_vort4 = dudz - dwdx
x_vort4 = dwdy - dvdz

# %%
ds4=xr.open_dataset('cm1out_000009.nc')

num_x = ds.ni
num_y = ds.nj
num_z = ds.nk

dx = ds['xh']*units('m')
dy = ds['yh']*units('m')
dz = ds['zh']*units('m')

u = ds['u']
v = ds['v']
w = ds['w']

x_space = 31.25*units('m')
y_space = 31.25*units('m')
z_space = 15.625*units('m')

lev = 0
u = u.isel(nk=lev,time=0)
v = v.isel(nk=lev,time=0)
w = w.isel(nk=lev,time=0)

dz[0] # z direction grid delta

# z_vort tilting term
dudz5 = mpcalc.first_derivative(u, delta=dz[1]-dz[0])
dvdz5 = mpcalc.first_derivative(v, delta=dz[1]-dz[0])
dwdy5 = mpcalc.first_derivative(w, delta=dy[1]-dy[0])
dwdx5 = mpcalc.first_derivative(w, delta=dx[1]-dx[0])

# z vort stretching term
dudx5 = mpcalc.first_derivative(u, delta=dx[1]-dx[0])
dvdy5 = mpcalc.first_derivative(v, delta=dy[1]-dy[0])
dwdz5 = mpcalc.first_derivative(w, delta=dz[1]-dz[0])

# z vort, y vort, x vort components
dvdx5 = mpcalc.first_derivative(v, delta=dx[1]-dx[0])
dudy5 = mpcalc.first_derivative(u, delta=dy[1]-dy[0])
dudz5 = mpcalc.first_derivative(u, delta=dz[1]-dz[0])
dwdx5 = mpcalc.first_derivative(w, delta=dx[1]-dx[0])
dwdy5 = mpcalc.first_derivative(w, delta=dy[1]-dy[0])
dvdz5 = mpcalc.first_derivative(v, delta=dz[1]-dz[0])

z_vort5 = dvdx - dudy
y_vort5 = dudz - dwdx
x_vort5 = dwdy - dvdz

# %%
zeta = [z_vort, z_vort2, z_vort3, z_vort4, z_vort5]
t = [1, 2, 3, 4, 5]

# %%
plt.contourf(dx, dy, z_vort, cmap='viridis')
plt.colorbar()

# %%
dzetadt = mpcalc.first_derivative(zeta, delta=t[1]-t[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 dzetadt = mpcalc.first_derivative(zeta, delta=t[1]-t[0])
#
# File /knight/mamba_aug23/envs/aug23_env/lib/python3.11/site-packages/metpy/calc/tools.py:951, in xarray_derivative_wrap.<locals>.wrapper(f, **kwargs)
#     947 @functools.wraps(func)
#     948 def wrapper(f, **kwargs):
#     949     if 'x' in kwargs or 'delta' in kwargs:
#     950         # Use the usual DataArray to pint.Quantity preprocessing wrapper
# --> 951         return preprocess_and_wrap()(func)(f, **kwargs)
#     952     elif isinstance(f, xr.DataArray):
#     953         # Get axis argument, defaulting to first dimension
#     954         axis = f.metpy.find_axis_name(kwargs.get('axis', 0))
#
# ...
