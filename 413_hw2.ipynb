# %%
local_path='../atm413/'
file_name=local_path+'Assignment2_Data.csv'

# %%
import pandas as pd
data=pd.read_csv(local_path+file_name)

# %%
data
# Out:
#      YEAR  MONTH  DAY DAY OF WEEK  VEHICLE COUNT  TEMPERATURE  SNOWFALL
# 0    2017     12    1      Friday          19508           38       0.0
# 1    2017     12    2    Saturday          18308           34       0.0
# 2    2017     12    3      Sunday          13302           36       0.0
# 3    2017     12    4      Monday          16335           30       0.0
# 4    2017     12    5     Tuesday          16669           46       0.0
# ..    ...    ...  ...         ...            ...          ...       ...
# 253  2020      2   24      Monday          14778           46       0.0
# 254  2020      2   25     Tuesday          15494           42       0.0
# 255  2020      2   26   Wednesday          15698           39       0.0
# 256  2020      2   27    Thursday          15433           34       0.0
# 257  2020      2   28      Friday          18132           30       0.0
#
# [258 rows x 7 columns]

# %%
import numpy as np
day=np.array(data['DAY OF WEEK'])
numberofcars=np.array(data['VEHICLE COUNT'])
#print(day)
#print(numberofcars)

week=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']


#while i<7:
    #w=week[i]
    #print(day[w])
    #if w in day==True:   
    #i=i+1
i=0
mo=[]
tu=[]
we=[]
th=[]
fr=[]
sa=[]
su=[]
for x in day:
    if day[i]=='Monday':
        mo.append(day)
    elif day[i]=='Tuesday':
        tu.append(day)
    elif day[i]=='Wednesday':
        we.append(day)
    elif day[i]=='Thursday':
        th.append(day)
    elif day[i]=='Friday':
        fr.append(day)
    elif day[i]=='Saturday':
        sa.append(day)
    elif day[i]=='Sunday':
        su.append(day)
    i=i+1
mo
# Out:
# [array(['Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday',
#         'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday',
#         'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday',
#         'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday',
#         'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday',
#         'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday',
#         'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday',
#         'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday',
#         'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday',
#         'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday',
#         'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday',
#         'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday',
#         'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday',
# ...
