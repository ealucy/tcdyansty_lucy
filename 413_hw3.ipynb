# %%
file = 'Assignment3_Data.csv'
import pandas as pd
df=pd.read_csv(file)

# %%
windspeed=df['Wind speed']
cat=df['Saffir-Simpson category']
damage=df['Normalized damage']

# %%
i=0
for x in cat:
    if cat[i]==1:
        print(windspeed.mean())
    if cat[i]==2:
        print(windspeed.mean())
    i=i+1
# Out:
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# 92.33207547169812
# ...
