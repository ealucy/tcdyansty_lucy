# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def x(t):
    return np.sin(.0001*t)/.0001
def y(t):
    return np.cos(.0001*t)/.0001

# %%
t = np.arange(0, 5184000, 10)

# %%
x_t = x(t)
y_t = y(t)

# %%
plt.plot(x_t, y_t)
